# %%
import numpy
import matplotlib
import cv2

# %%
from matplotlib import pyplot as plt
img = cv2.imread('img.jpg')

# %%
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (640, 640, 3)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
a = numpy.asarray(img)

# %%
X = numpy.random.random((50,50)) # sample 2D array
plt.imshow(X)
plt.show()

# %%
(X * 255).astype('uint8')
# aray gen
# Out:
# array([[182,  48],
#        [169,   2]], dtype=uint8)

# %%
P=numpy.array([[0,0],[0,0]])
fool=(P * 255).astype('uint8')
plt.imshow(P)
plt.show()

# %%
P.dtype
fool
# plt.imshow(fool, cmap='gray')
# Out:
# array([[76, 76],
#        [76, 76]], dtype=uint8)
